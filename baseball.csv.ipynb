# %% [markdown]
# # Base ball case study :-

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.sample()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER  ERA  CG  SHO  \
# 5  93  891  5509  1480  308  17  232  570  1151  88  670  609  3.8   7   10
#
#    SV   E
# 5  34  88

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#checking the data types
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.shape
# Out:
# (30, 17)

# %%
#checking the null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.drop_duplicates()
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df=df.drop(['CG','SB'],axis=1)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   RA   ER   ERA  SHO  SV    E
# 0  95  724  5575  1497  300  42  139  383   973  641  601  3.73    8  56   88
# 1  83  696  5467  1349  277  44  156  439  1264  700  653  4.07   12  45   86
# 2  81  669  5439  1395  303  29  141  533  1157  640  584  3.67   10  38   79
# 3  76  622  5533  1381  260  27  136  404  1231  701  643  3.98    9  37  101
# 4  74  689  5605  1515  289  49  151  455  1259  803  746  4.64   12  35   86

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# ...

# %%
df.corr()['E'].sort_values()
# Out:
# HR    -0.207597
# SHO   -0.115716
# W     -0.089485
# BB    -0.075685
# H     -0.033173
# SV    -0.025636
# R     -0.023262
# 2B     0.105754
# ERA    0.113137
# 3B     0.126678
# ER     0.136921
# SO     0.155133
# RA     0.198996
# AB     0.316743
# E      1.000000
# Name: E, dtype: float64

# %% [markdown]
# correlation using heatmap

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatterplot:

# %%
# sns.scatterplot()

# %%
sns.scatterplot(x='W',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %%
sns.scatterplot(x='R',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='E'>

# %%
sns.scatterplot(x='AB',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='E'>

# %%
sns.scatterplot(x='H',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='E'>

# %%
sns.scatterplot(x='SHO',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='E'>

# %%
sns.scatterplot(x='SV',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='E'>

# %%
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# # Describing Datasets:

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#         mean     std      min      25%      50%      75%      max
# W      80.97   10.45    63.00    74.00    81.00    87.75   100.00
# R     688.23   58.76   573.00   651.25   689.00   718.25   891.00
# AB   5516.27   70.47  5385.00  5464.00  5510.00  5570.00  5649.00
# H    1403.53   57.14  1324.00  1363.00  1382.50  1451.50  1515.00
# 2B    274.73   18.10   236.00   262.25   275.50   288.75   308.00
# 3B     31.30   10.45    13.00    23.00    31.00    39.00    49.00
# HR    163.63   31.82   100.00   140.25   158.50   177.00   232.00
# BB    469.10   57.05   375.00   428.25   473.00   501.25   570.00
# SO   1248.20  103.76   973.00  1157.50  1261.50  1311.50  1518.00
# RA    688.23   72.11   525.00   636.25   695.50   732.50   844.00
# ER    635.83   70.14   478.00   587.25   644.50   679.25   799.00
# ERA     3.96    0.45     2.94     3.68     4.03     4.22     5.04
# SHO    11.30    4.12     4.00     9.00    12.00    13.00    21.00
# ...

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          RA          ER  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000  688.233333  635.833333
# std    10.452355   31.823309   57.053725   103.75947   72.108005   70.140786
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('variable summary')
plt.savefig('heatmap.png')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   RA      30 non-null     int64
#  10  ER      30 non-null     int64
#  11  ERA     30 non-null     float64
#  12  SHO     30 non-null     int64
#  13  SV      30 non-null     int64
#  14  E       30 non-null     int64
# dtypes: float64(1), int64(14)
# memory usage: 3.6 KB

# %% [markdown]
# # checking Outliers:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrow=17

# %%
collist
# Out:
# array(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'RA', 'ER',
#        'ERA', 'SHO', 'SV', 'E'], dtype=object)

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# # Data cleaning:

# %%
df.corr()["E"].sort_values()
# Out:
# HR    -0.207597
# SHO   -0.115716
# W     -0.089485
# BB    -0.075685
# H     -0.033173
# SV    -0.025636
# R     -0.023262
# 2B     0.105754
# ERA    0.113137
# 3B     0.126678
# ER     0.136921
# SO     0.155133
# RA     0.198996
# AB     0.316743
# E      1.000000
# Name: E, dtype: float64

# %%
df=df.drop(['2B','ERA','3B','ER','RA'],axis=1)
df
# Out:
#       W    R    AB     H   HR   BB    SO  SHO  SV    E
# 0    95  724  5575  1497  139  383   973    8  56   88
# 1    83  696  5467  1349  156  439  1264   12  45   86
# 2    81  669  5439  1395  141  533  1157   10  38   79
# 3    76  622  5533  1381  136  404  1231    9  37  101
# 4    74  689  5605  1515  151  455  1259   12  35   86
# 5    93  891  5509  1480  232  570  1151   10  34   88
# 6    87  764  5567  1397  212  554  1227    4  48   93
# 7    81  713  5485  1370  217  418  1331   10  43   77
# 8    80  644  5485  1383  167  436  1310   12  60   95
# 9    78  748  5640  1495  161  478  1148   10  40   97
# 10   88  751  5511  1419  172  503  1233    9  45  119
# 11   86  729  5459  1363  230  486  1392   13  39   85
# 12   85  661  5417  1331  176  435  1150   12  46   93
# 13   76  656  5544  1379  198  478  1336   12  45   94
# 14   68  694  5600  1405  146  475  1119   15  28  126
# 15  100  647  5484  1386  137  506  1267   15  62   96
# ...

# %%
from scipy.stats import zscore

# %%
df.plot(kind = 'box', subplots = True, layout = (4,4), fontsize = 8, figsize = (12,12))
# Out:
# W          AxesSubplot(0.125,0.71587;0.168478x0.16413)
# R       AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# AB      AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# H       AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# HR        AxesSubplot(0.125,0.518913;0.168478x0.16413)
# BB     AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# SO     AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# SHO    AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# SV        AxesSubplot(0.125,0.321957;0.168478x0.16413)
# E      AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# dtype: object

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,r2_score
from sklearn.model_selection import cross_val_score

# %%
Model = LinearRegression()
Model.fit(train_x,train_y)
pred_model = Model.predict(test_x)
print("Accuracy score", r2_score(test_y, pred_model)*100)
# Out:
# Accuracy score -218.43960415957798

# %%
print('Mean absolute error:', mean_absolute_error(test_y, pred_model))
print('Mean squared error:', mean_squared_error(test_y, pred_model))
print('Root Mean squared error:', np.sqrt(mean_squared_error(test_y, pred_model)))
print('R2 score is:', r2_score(test_y, pred_model))
# Out:
# Mean absolute error: 64.4279960122547
# Mean squared error: 5939.606261140929
# Root Mean squared error: 77.06884105227566
# R2 score is: -2.1843960415957797

# %%
Model.score(test_x,test_y)
# Out:
# -2.1843960415957797

# %% [markdown]
# # Decision tree

# %%
dt = DecisionTreeRegressor()
dt.fit(train_x,train_y)
pred_dt = dt.predict(test_x)
print("Accuracy score", r2_score(test_y, pred_dt)*100)
# Out:
# Accuracy score -144.43021385595998

# %% [markdown]
# # SVM

# %%
svr=SVR()
svr.fit(train_x,train_y)
predlr = svr.predict(test_x)
print("Accuracy score", r2_score(test_y, predlr)*100)
# Out:
# Accuracy score -137.57908196705233

# %% [markdown]
# # Gradient Boosting

# %%
gbr = GradientBoostingRegressor()
gbr.fit(train_x,train_y)
pred_gbr = gbr.predict(test_x)
print("Accuracy score", r2_score(test_y, pred_gbr)*100)
# Out:
# Accuracy score -45.42452219102313

# %%
plt.scatter(test_y,pred_model)
plt.xlabel("ACTUAL CHANCE OF WIN")
plt.ylabel("PREDICTED CHANCE OF WIN")
plt.title("ACTUAL VS MODEL PREDICTED")
plt.show()

# %% [markdown]
# # Cross validation

# %%
scr = cross_val_score(Model, train_x, train_y, cv=5)
print("Cross validation score of linear regression model is",scr.mean())
# Out:
# Cross validation score of linear regression model is -11.101746210130589

# %%
scr = cross_val_score(gbr, train_x, train_y, cv=5)
print("Cross validation score of Gradient boosting model is",scr.mean())
# Out:
# Cross validation score of Gradient boosting model is -0.5182556189969706
